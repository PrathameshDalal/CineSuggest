# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import ast

# %%
movies_metadata = pd.read_csv('1950-2019/bollywood_full_1950-2019.csv')
crew_data = pd.read_csv('1950-2019/bollywood_crew_data_1950-2019.csv')
crew = pd.read_csv('1950-2019/bollywood_crew_1950-2019.csv')

# %%
movies_metadata = movies_metadata.merge(crew, on='imdb_id')

# %%
movies_metadata
# Out:
#                                    title_x    imdb_id  \
# 0                 Uri: The Surgical Strike  tt8291224
# 1                            Battalion 609  tt9472208
# 2     The Accidental Prime Minister (film)  tt6986710
# 3                          Why Cheat India  tt8108208
# 4                          Evening Shadows  tt6028796
# ...                                    ...        ...
# 4420                   Samadhi (1950 film)  tt0268614
# 4421                   Sangram (1950 film)  tt0244182
# 4422                    Sargam (1950 film)  tt0269826
# 4423              Sheesh Mahal (1950 film)  tt0243555
# 4424                   Meena Bazaar (film)  tt0213081
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies_metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4425 entries, 0 to 4424
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           4425 non-null   object
#  1   imdb_id           4425 non-null   object
#  2   poster_path       3672 non-null   object
#  3   wiki_link         4425 non-null   object
#  4   title_y           4425 non-null   object
#  5   original_title    4425 non-null   object
#  6   is_adult          4425 non-null   int64
#  7   year_of_release   4425 non-null   object
#  8   runtime           4425 non-null   object
#  9   genres            4425 non-null   object
#  10  imdb_rating       4412 non-null   float64
#  11  imdb_votes        4412 non-null   float64
#  12  story             4157 non-null   object
#  13  summary           4424 non-null   object
#  14  tagline           697 non-null    object
#  15  actors            4415 non-null   object
# ...

# %%
movies_metadata.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          753
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating           13
# imdb_votes            13
# story                268
# summary                1
# tagline             3728
# actors                10
# wins_nominations    3012
# release_date        1314
# directors              0
# writers                0
# dtype: int64

# %%
movies = movies_metadata['imdb_id', 'original_title', 'genres', 'summary', 'actors', 'directors', ]
